# %%
import matplotlib
# %matplotlib widget
from auxiliary.dataset_shapenet import *
# Out:
# Loaded compiled CUDA chamfer distance

# %%
d = ShapeNetSeg(mode="MEMORIZE", knn=False, sample=False, class_choice="Chair",
                data_augmentation_Z_rotation=False, data_augmentation_Z_rotation_range=40, npoints=400,
                random_translation=False, anisotropic_scaling=False, shuffle=False, get_single_shape=True)
# Out:
# Reload parts from :  ./data/dataset_shapenet/parts_by_cat_Chair.json
# size of MEMORIZE dataset : 4
# Dataset normalization : BoundingBox
# preprocess dataset...
#  dataset : 4
# Ellapsed time : "0.09

# %%
d[0]
# Out:
# (tensor([[-2.0365e-01, -2.9827e-01, -2.7505e-01,  ...,  4.9300e-01,
#           -3.9200e-01,  1.4000e+01],
#          [-4.9096e-01,  2.8766e-01, -2.5888e-01,  ..., -9.7700e-02,
#           -2.8040e-01,  1.2000e+01],
#          [-4.4701e-01,  7.3576e-01, -2.7865e-01,  ...,  6.9970e-02,
#            4.6140e-01,  1.2000e+01],
#          ...,
#          [-3.6040e-01,  1.1376e-01, -4.8557e-03,  ...,  5.7720e-01,
#            1.3620e-03,  1.2000e+01],
#          [-4.9321e-01,  7.6259e-01, -2.7989e-01,  ..., -7.9430e-02,
#           -6.5710e-01,  1.2000e+01],
#          [ 3.0965e-01, -3.4265e-01, -2.5550e-01,  ..., -9.9230e-01,
#            6.4370e-02,  1.4000e+01]]),
#  'Chair',
#  tensor([[ 0.9503,  0.0000,  0.3114],
#          [ 0.0000,  1.0000,  0.0000],
#          [-0.3114,  0.0000,  0.9503]]),
#  './data/dataset_shapenet/03001627/1015e71a0d21b127de03ab2a27ba7531.txt')

# %%
import auxiliary.visualization as vis

# %%
vis.visualize_points(d[0][0][:,:3], c=d[0][0][:,6], bound=1.0, show=True)

# %%
vis.visualize_points(d[1][0][:,:3], c=d[1][0][:,6], bound=1.0, show=True)

# %%
vis.visualize_points(d[2][0][:,:3], c=d[2][0][:,6], bound=1.0, show=True)

# %%
vis.visualize_points(d[3][0][:,:3], c=d[3][0][:,6], bound=1.0, show=True)
